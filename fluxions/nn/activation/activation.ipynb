# %%
import fluxions
from fluxions.tensor import Tensor

# This verifies both the package install AND the class import
t = Tensor([1, 2, 3])
print(f"Success! Created: {t}")
print(f"Library file is at: {fluxions.__file__}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import fluxions
#       2 from fluxions.tensor import Tensor
#       4 # This verifies both the package install AND the class import
#
# ModuleNotFoundError: No module named 'fluxions'
